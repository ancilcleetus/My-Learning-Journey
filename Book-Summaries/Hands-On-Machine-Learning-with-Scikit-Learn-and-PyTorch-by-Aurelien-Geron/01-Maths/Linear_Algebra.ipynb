# %% [markdown]
# # Name of the Notebook

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 📖 TABLE OF CONTENTS
#
# - [Section 1]()
#   - [Subsection 1]()
#     - [Subsubsection 1]()
#     - [Subsubsection 2]()
#   - [Subsection 2]()
#     - [Subsubsection 1]()
#     - [Subsubsection 2]()
# - [Section 2]()
#   - [Subsection 1]()
#     - [Subsubsection 1]()
#     - [Subsubsection 2]()
#   - [Subsection 2]()
#     - [Subsubsection 1]()
#     - [Subsubsection 2]()

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 1. First Topic

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # References

# %% [markdown]
# - **[IBM's Blog: A new tool to unlock data from enterprise documents for generative AI](https://research.ibm.com/blog/docling-generative-AI)**
# - **[Docling Webpage](https://ds4sd.github.io/docling/)**

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %%
# Notebook Template

from IPython import display
display.Image("data/images/Notebook_Template-01.jpg")

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)
