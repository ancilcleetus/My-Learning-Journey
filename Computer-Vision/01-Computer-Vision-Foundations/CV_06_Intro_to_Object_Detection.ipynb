# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# Object detection is a computer vision task that involves identifying and locating objects within an image. Object detection not only recognizes objects in an image but also determines their positions. This task combines two key aspects:
#
# 1. **Classification:** Identifying what objects are present.
#
# 2. **Localization:** Determining where each object is in the image, typically using bounding boxes.

# %%
# Image Classification Vs Object Detection

from IPython import display
display.Image("data/images/CV_06_Intro_to_Object_Detection-01.jpg")

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 2. Classification Vs Localization Vs Object Detection

# %% [markdown]
# ## 1. Classification

# %%
# Classification

from IPython import display
display.Image("data/images/CV_06_Intro_to_Object_Detection-02.jpg")

# %% [markdown]
# ## 2. Localization or Object Localization

# %% [markdown]
# Object Localization $\implies$ Classification with Single Label + Object Location

# %%
# Localization or Object Localization

from IPython import display
display.Image("data/images/CV_06_Intro_to_Object_Detection-03.jpg")

# %% [markdown]
# ## 3. Object Detection

# %% [markdown]
# Object Detection $\implies$ Requires us to detect all objects and all classes and all the bounding boxes in a given image irrespective of the shape and size of the object

# %%
# Object Detection

from IPython import display
display.Image("data/images/CV_06_Intro_to_Object_Detection-04.jpg")

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)

# %% [markdown]
# # 2. Evolution of Image Classification Architectures

# %%
# Evolution of Image Classification Architectures

from IPython import display
display.Image("data/images/CV_06_Intro_to_Object_Detection-0x.jpg")

# %% [markdown]
# Convolutional neural networks (CNN) are among the more popular neural network frameworks that are used in complex applications like deep learning models for computer vision and image recognition.
#
# Over the years, CNNs have undergone a considerable amount of rework and advancement. This has left us with a plethora of CNN models. Let's discuss the more important CNNs out of all these variants.

# %% [markdown]
# ## 1. LeNet-5

# %% [markdown]
# - **Architecture:** LeNet-5 has 2 convolutional and 3 fully connected layers. It has trainable weights and a sub-sampling layer (now known as the pooling layer). LeNet5 has about 60,000 parameters.
#
# - **Year of Release:** 1998
#
# - **About:** Developed by Yann LeCunn as he applied a backdrop style to Fukushima's convolutional neural network architecture.
#
# - **USP:** LeNet5 can be considered the standard template for all modern CNNs as all CNNs follow the pattern of stacking convolutional and pooling layers, and terminating the model with one or more fully-connected layers.

# %% [markdown]
# ![rainbow](https://github.com/ancilcleetus/My-Learning-Journey/assets/25684256/839c3524-2a1d-4779-85a0-83c562e1e5e5)
